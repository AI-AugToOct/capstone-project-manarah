# %%
from openai import OpenAI

# مفتاح API
API_KEY = "sk-proj-"

client = OpenAI(api_key=API_KEY)

with open("/Users/anody/Downloads/v14044g50000d2u5l2fog65qra6os9k0.mp4", "rb") as audio_file:
    transcription = client.audio.transcriptions.create(
        model="whisper-1",
        file=audio_file,
        language="ar"
    )

print(transcription.text)

with open("output_ar.txt", "w", encoding="utf-8") as f:
    f.write(transcription.text)
# Out:
# نفس الموال نفس الموال يا عري ايش الهرجة يا اخي انت بتقول يا عري انا بقول يا تفلة ايش
